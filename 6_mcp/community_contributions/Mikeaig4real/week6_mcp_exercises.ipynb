# %% [markdown]
# # Module 6 Exercises - Mikeaig4real
#
# This notebook uses a modular local MCP server and client agent.

# %%
import asyncio
from module6_mcp_app.client_agent import run_mcp_prompt

# %%
print(asyncio.run(run_mcp_prompt('Give me a short headline about AI safety and include date')))
